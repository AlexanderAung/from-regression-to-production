# %% [markdown]
# # Test

# %%
import os
from pathlib import Path

print(Path.cwd())
# Out:
# /Users/boy/Desktop/you/from-regression-to-production/traffic_sign_detection_and_classification/notebooks

# %%
file_path_str = "../data/train/3"
dir_path = Path(file_path_str)
files = list(dir_path.glob("*.png"))

#print(type(files)) # <class 'list'>
#print(len(files))

for i,img in enumerate(files):
    if i < 10:
        print(img.name)
# Out:
# 00003_00046_00013.png
# 00003_00046_00007.png
# 00003_00010_00011.png
# 00003_00010_00005.png
# 00003_00001_00022.png
# 00003_00032_00024.png
# 00003_00023_00003.png
# 00003_00023_00017.png
# 00003_00032_00018.png
# 00003_00045_00027.png

# %%
print(Path.cwd())
print(dir_path)
print(type(dir_path))
# Out:
# /Users/boy/Desktop/you/from-regression-to-production/traffic_sign_detection_and_classification/notebooks
# ../data/train/0
# <class 'pathlib.PosixPath'>

# %%
for i, img_p in enumerate(files[:10]):
    print(type(img_p))
    print(img_p)
# Out:
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00005_00023.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00006_00017.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00006_00003.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00003_00018.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00003_00024.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00000_00010.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00000_00004.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00000_00005.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00000_00011.png
# <class 'pathlib.PosixPath'>
# ../data/train/0/00000_00003_00025.png

# %%
from PIL import Image
import matplotlib.pyplot as plt


for i, img_path in enumerate(files[200:210]):
    img = Image.open(img_path)
    plt.imshow(img)
    plt.axis("off")
    plt.title(img_path.name)
    plt.show()

# %% [markdown]
# # Tensors

# %%
import torch 
import numpy as np

# %%
np_d = np.eye(3)
np_d
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
pt_d = torch.from_numpy(np_d)
pt_d
# Out:
# tensor([[1., 0., 0.],
#         [0., 1., 0.],
#         [0., 0., 1.]], dtype=torch.float64)

# %%
shape = (2, 3, )
ran_torch = torch.rand(shape)
ran_torch
# Out:
# tensor([[0.1743, 0.1541, 0.0647],
#         [0.5834, 0.4817, 0.4906]])
